# %% [markdown]
# # Process GWPT dataset from raw to clean.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Read in the data into a single dataframe
# Join the small and large dataset (> 10MW and <10MW) together.

# %%
# set up parameters
INPUT_FILE = r"..\data\raw\Global-Wind-Power-Tracker-December-2023.xlsx"
WORKSHEET_BIG_DATASET = "Data"
WORKSHEET_SMALL_DATASET = "Below Threshold"
OUTPUT_FILE_FULL_DATASET = r"..\data\clean\gwpt.parquet"
OUTPUT_FILE_GEO = r"..\data\clean\geo.parquet"
OUTPUT_FILE_AGG = r"..\data\clean\gwpt_agg.parquet"

# %%
# read in the big & small dataset
df_big = pd.read_excel(INPUT_FILE, sheet_name=WORKSHEET_BIG_DATASET)
df_small = pd.read_excel(INPUT_FILE, sheet_name=WORKSHEET_SMALL_DATASET)
print(f"The dimensions of the big table are {df_big.shape}")
print(f"The dimensions of the small table are {df_small.shape}")
# Out:
# The dimensions of the big table are (26523, 29)
# The dimensions of the small table are (899, 29)

# %%
#combining them 
df = pd.concat([df_big, df_small])
df.head(5)
# Out:
#   Date Last Researched  Country         Project Name Phase Name  \
# 0           2023/07/03  Algeria  Kabertene wind farm        NaN
# 1           2023/07/03  Algeria  Khenchela wind farm        NaN
# 2           2023/07/03  Algeria   Timimoun wind farm        NaN
# 3           2023/07/06   Angola   Benjamin wind farm        NaN
# 4           2023/07/06   Angola     Cacula wind farm        NaN
#
#   Project Name in Local Language / Script        Other Name(s)  Capacity (MW)  \
# 0          مزرعة رياح كبيرت,, مدينة أدرار  Kabartene wind farm           10.0
# 1                        مزرعة رياح خنشلة                  NaN           20.0
# 2                                     NaN        Timimoun Sktm           50.0
# 3                                     NaN                  NaN           52.0
# 4                                     NaN                  NaN           88.0
#
#   Installation Type            Status  Start year  ...  \
# 0           onshore         operating      2014.0  ...
# 1           onshore         cancelled         NaN  ...
# 2           unknown         cancelled         NaN  ...
# 3           onshore  pre-construction      2028.0  ...
# 4           onshore  pre-construction      2029.0  ...
#
#    Local area (taluk, county) Major area (prefecture, district)  \
# 0             Tsabit District                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#       State/Province           Subregion  Region  GEM location ID  \
# 0              Adrar     Northern Africa  Africa          L900124
# 1                NaN     Northern Africa  Africa          L900137
# 2                NaN     Northern Africa  Africa          L916594
# 3  Benguela Province  Sub-Saharan Africa  Africa          L916595
# 4     Huíla Province  Sub-Saharan Africa  Africa          L916596
#
#    GEM phase ID Other IDs (location) Other IDs (unit/phase)  \
# 0       G900162                  NaN                    NaN
# 1       G900178                  NaN                    NaN
# 2       G920620                  NaN                    NaN
# 3       G920621                  NaN                    NaN
# 4       G920622                  NaN                    NaN
#
#                                Wiki URL
# 0  https://gem.wiki/Kabertene_wind_farm
# 1  https://gem.wiki/Khenchela_wind_farm
# 2   https://gem.wiki/Timimoun_wind_farm
# 3   https://gem.wiki/Benjamin_wind_farm
# 4     https://gem.wiki/Cacula_wind_farm
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Explore the data
# ### Fix datatypes

# %%
# check and correct the types of the imported data
df.dtypes
# Out:
# Date Last Researched                         object
# Country                                      object
# Project Name                                 object
# Phase Name                                   object
# Project Name in Local Language / Script      object
# Other Name(s)                                object
# Capacity (MW)                               float64
# Installation Type                            object
# Status                                       object
# Start year                                  float64
# Retired year                                float64
# Operator                                     object
# Operator Name in Local Language / Script     object
# Owner                                        object
# Owner Name in Local Language / Script        object
# Latitude                                    float64
# Longitude                                   float64
# Location accuracy                            object
# City                                         object
# Local area (taluk, county)                   object
# Major area (prefecture, district)            object
# State/Province                               object
# Subregion                                    object
# Region                                       object
# GEM location ID                              object
# GEM phase ID                                 object
# Other IDs (location)                         object
# Other IDs (unit/phase)                       object
# Wiki URL                                     object
# dtype: object

# %%
# convert the date columns which are in object (string) to date types
df["Date Last Researched"] = pd.to_datetime(df["Date Last Researched"], format='ISO8601')

# %%
# convert the float columns which are whole numbers to ints
df['Start year'] = df['Start year'].astype('Int64')
df['Retired year'] = df['Retired year'].astype('Int64')

# %% [markdown]
# ### Look for missing values

# %%
missing_data = df.isna().sum()
missing_data
# Out:
# Date Last Researched                            0
# Country                                         0
# Project Name                                    0
# Phase Name                                  16831
# Project Name in Local Language / Script     15849
# Other Name(s)                               21906
# Capacity (MW)                                   0
# Installation Type                               0
# Status                                          0
# Start year                                   9919
# Retired year                                27156
# Operator                                    10210
# Operator Name in Local Language / Script    20932
# Owner                                        7345
# Owner Name in Local Language / Script       21411
# Latitude                                        0
# Longitude                                       0
# Location accuracy                               0
# City                                        15172
# Local area (taluk, county)                   9059
# Major area (prefecture, district)           14755
# State/Province                               4719
# Subregion                                       0
# Region                                          0
# GEM location ID                                 0
# GEM phase ID                                    0
# Other IDs (location)                        21012
# Other IDs (unit/phase)                      26478
# Wiki URL                                        0
# dtype: int64

# %%
# missing capacity:
capacity_na_count = df['Capacity (MW)'].isna().sum()
print(f"Number of rows with NaN in 'Capacity (MW)': {capacity_na_count}")
# Out:
# Number of rows with NaN in 'Capacity (MW)': 0

# %%
# missing start_year
start_na_count = df['Start year'].isna().sum()
print(f"Number of rows with NaN in 'Start year': {start_na_count}")
print(f"Percentage of rows with 'Start year' info: {(df.shape[0]-start_na_count)/df.shape[0]*100} %")
# Out:
# Number of rows with NaN in 'Start year': 9919
# Percentage of rows with 'Start year' info: 63.8283130333309 %

# %%
# missing region:
region_na_count = df['Region'].isna().sum()
print(f"Number of rows with NaN in 'Region': {region_na_count}")
# Out:
# Number of rows with NaN in 'Region': 0

# %%
# missing country:
country_na_count = df['Country'].isna().sum()
print(f"Number of rows with NaN in 'Country': {country_na_count}")
# Out:
# Number of rows with NaN in 'Country': 0

# %%
# missing coordinates:
coord_na_count = df[df['Latitude'].isna() | df['Longitude'].isna()].shape[0]
print(f"Number of rows with NaN in 'Lat or Lon': {coord_na_count}")
# Out:
# Number of rows with NaN in 'Lat or Lon': 0

# %% [markdown]
# ### Check categorical columns

# %%
# check country
unique_countries = df["Country"].unique()
print("The distinct values for 'Country' are:")
print(unique_countries)
print(f"There are {len(unique_countries)} unique countries in the dataset.")
# Out:
# The distinct values for 'Country' are:
# ['Algeria' 'Angola' 'Cabo Verde' 'Cameroon' 'Chad' 'Djibouti' 'Egypt'
#  'Ethiopia' 'Ghana' 'Kenya' 'Libya' 'Madagascar' 'Malawi' 'Mali'
#  'Mauritania' 'Mauritius' 'Morocco' 'Mozambique' 'Namibia' 'Niger'
#  'Nigeria' 'Réunion' 'Senegal' 'South Africa' 'Sudan' 'Tanzania' 'Togo'
#  'Tunisia' 'Uganda' 'Western Sahara' 'Zambia' 'Zimbabwe' 'Argentina'
#  'Aruba' 'Barbados' 'Bermuda' 'Bolivia' 'Bonaire, Sint Eustatius and Saba'
#  'Brazil' 'Canada' 'Chile' 'Colombia' 'Costa Rica' 'Cuba' 'Curaçao'
#  'Dominican Republic' 'Ecuador' 'El Salvador' 'Greenland' 'Grenada'
#  'Guadeloupe' 'Guatemala' 'Guyana' 'Honduras' 'Jamaica' 'Martinique'
#  'Mexico' 'Nicaragua' 'Panama' 'Peru' 'Puerto Rico' 'Saint Lucia'
#  'United States' 'Uruguay' 'Venezuela' 'Vietnam' 'South Korea' 'Jordan'
#  'Philippines' 'Japan' 'Armenia' 'Pakistan' 'Türkiye' 'Cyprus' 'Israel'
#  'Iran' 'Kazakhstan' 'Saudi Arabia' 'Syria' 'Yemen' 'Indonesia' 'Oman'
#  'Thailand' 'Myanmar' 'Sri Lanka' 'Azerbaijan' 'Uzbekistan' 'Bangladesh'
#  'Georgia' 'Mongolia' 'Kyrgyzstan' 'Maldives' 'Bhutan' 'Macao'
#  'United Arab Emirates' 'Lebanon' 'Afghanistan' 'Hong Kong' 'Cambodia'
#  'Laos' 'Kuwait' 'Singapore' 'Iraq' 'Taiwan' 'Åland Islands' 'Albania'
#  'Austria' 'Belarus' 'Belgium' 'Bosnia and Herzegovina' 'Bulgaria'
#  'Croatia' 'Czech Republic' 'Denmark' 'Estonia' 'Faroe Islands' 'Finland'
#  'France' 'Germany' 'Greece' 'Guernsey' 'Hungary' 'Ireland' 'Isle of Man'
#  'Italy' 'Kosovo' 'Latvia' 'Lithuania' 'Luxembourg' 'Malta' 'Moldova'
#  'Montenegro' 'Netherlands' 'North Macedonia' 'Norway' 'Poland' 'Portugal'
#  'Romania' 'Russia' 'Serbia' 'Slovakia' 'Slovenia' 'Spain' 'Sweden'
#  'Switzerland' 'Ukraine' 'United Kingdom' 'American Samoa' 'Australia'
#  'Fiji' 'Guam' 'New Caledonia' 'New Zealand' 'India' 'China']
# There are 155 unique countries in the dataset.

# %%
# check Installation Type
unique_installation_types = df["Installation Type"].unique()
print("The distinct values for 'Installation Type' are:")
print(unique_installation_types)
# Out:
# The distinct values for 'Installation Type' are:
# ['onshore' 'unknown' 'offshore mount unknown' 'offshore hard mount'
#  'offshore floating']

# %%
# check status Type
unique_status = df["Status"].unique()
print("The distinct values for 'Status' are:")
print(unique_status)
# Out:
# The distinct values for 'Status' are:
# ['operating' 'cancelled' 'pre-construction' 'announced' 'construction'
#  'shelved' 'retired' 'mothballed']

# %%
# check Installation Type
unique_region = df["Region"].unique()
print("The distinct values for 'Region' are:")
print(unique_region)
# Out:
# The distinct values for 'Region' are:
# ['Africa' 'Americas' 'Asia' 'Europe' 'Oceania']

# %% [markdown]
# ## Clean the data
# ### Drop columns you will never use

# %%
columns_to_drop = ["Project Name in Local Language / Script", 
                   "Owner Name in Local Language / Script",
                   "GEM location ID",
                   "GEM phase ID",
                   "Other IDs (location)",
                   "Other IDs (unit/phase)",
                   "Other Name(s)",
                   "Date Last Researched"
                   ]
df = df.drop(columns=columns_to_drop)

# %% [markdown]
# ### Drop rows you will never use (outliers that are proven wrong and will mess up the viz)

# %%
df = df[df["Capacity (MW)"] < 10000]

# %% [markdown]
# ## Make first visuals

# %%
# stacked bar chart of installed capacity per region, colored by type

# Create a stacked bar chart
fig = px.bar(df, x='Region', y='Capacity (MW)', color='Status', title='Installed Capacity per Region')
fig.update_traces(marker_line_width=0)
fig.update_layout(barmode='stack')  # Set the barmode to 'stack' for stacking

# Show the plot
fig.show()
# Out:
# C:\dev\python\infovis\venv\Lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="25be87d0-0efa-4edf-ba12-43b5b9c1ad69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25be87d0-0efa-4edf-ba12-43b5b9c1ad69")) {                    Plotly.newPlot(                        "25be87d0-0efa-4edf-ba12-43b5b9c1ad69",                        [{"alignmentgroup":"True","hovertemplate":"Status=operating\u003cbr\u003eRegion=%{x}\u003cbr\u003eCapacity (MW)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"operating","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"width":0}},"name":"operating","offsetgroup":"operating","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americ ...

# %% [markdown]
# ## Create some aggregations (pre-processing) to speed up the later dash app

# %%
geo = df[["Region","Subregion","Country"]].drop_duplicates().reset_index()
geo = geo.reindex(columns=["Region", "Subregion", "Country"])
geo.shape
# Out:
# (155, 3)

# %%
agg = df.groupby(["Region", "Subregion", "Country", "Status", "Installation Type"]).sum("Capacity (MW)").reset_index()
agg.shape
# Out:
# (797, 10)

# %%
df["Capacity (MW)"].describe()
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Box(y=df["Capacity (MW)"], boxpoints='outliers', marker_color='skyblue', name="Capacity (MW)"))
fig.update_layout(title="Boxplot of Capacity (MW)",
                  yaxis_title="Capacity (MW)")
fig.show()
# Out:
# <div>                            <div id="19e75e38-b3ab-4774-a9d9-0cbb3066a51f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19e75e38-b3ab-4774-a9d9-0cbb3066a51f")) {                    Plotly.newPlot(                        "19e75e38-b3ab-4774-a9d9-0cbb3066a51f",                        [{"boxpoints":"outliers","marker":{"color":"skyblue"},"name":"Capacity (MW)","y":[10.0,20.0,50.0,52.0,88.0,84.0,48.0,40.0,30.0,62.0,42.0,40.0,36.0,44.0,36.0,40.0,100.0,40.0,13.0,40.0,100.0,100.0,5000.0,59.0,1100.0,160.0,502.0,700.0,1000.0,1500.0,4600.0,1500.0,1500.0,1500.0,250.0,240.0,220.0,120.0,160.0,2000.0,8000.0,1000.0,1000.0,263.0,500.0,283.0,2820.0,1500.0,1500.0,252.0,5000.0,30.0,33.0,30.0,47.0,85.0,80.0,120.0,121.0,51.0,153.0,150.0,30.0,45.0,45.0,100.0,150.0,120.0,120.0,152.0,700.0,100.0,300.0,134.0,150.0,42.0,100.0,100.0,100.0,200.0,76.0,150.0,75.0,160.0,250.0,200.0,70.0,280.0,50.0,76.5,50.0,90.0,300.0,50.0,60.0,50.0,40.0,50.0,50.0,36.0,61.0,100.0,50.0,260.0,100.0,50.0,50.0,400.0,80.0,100.0,300.0,14.0,11.5,11.0,30.0,50.0,60.0,26.0,240.0,12.0,150.0,50.0,151.2,100.0,200.0,4900.0,30.0,5000.0,22.0,30.0,2500.0,2500.0,80.0,102.0,100.0,50.0,54.0,200.0,120.0,60.0,7500.0,108.0,4000.0,10.0,51.0,270.0,120.0,10.0,10.0,12.0,210.0,3500.0,18.0,17.0,70.0,107.0,33.0,300.0,87.0,63.0,5000.0,60.0,30.0,60.0,60.0,44.0,46.0,50.0,34.0,40.0,2500.0,50.0,40.0,50.0,40.0,50.0,250.0,30.0,10.0,10.2,18.0,12.0,50.0,15.0,35.0,55.0,55.0,48.0,100.0,134.0,140.0,140.0,140.0,140.0,89.0,22.0,140.0,139.0,102.0,27.0,100.0,124.0,32.0,145.0,111.0,120.0,138.0,62.0,65.0,187.0,140.0,138.0,140.0,140.0,140.0,70.0,80.0,140.0,138.0,96.0,139.0,27.0,155.0,155.0,69.0,74.0,88.0,140.0,80.0,139.0,82.5,148.0,110.0,140.0,18.0,183.0,140.0,147.0,15.0,140.0,20.0,100.0,139.0,40.0,140.0,140.0,95.0,67.0,77.0,27.0,140.0,25.0,34.0,94.0,84.0,20.0,16.0,16.0,16.0,16.0,20.0,20.0,180.0,100.0,100.0,200.0,100.0,200.0,100.0,100.0,200.0,50.0,24.0,30.0,60.0,34.0,60.0,34.0,75.0,30.0,30.0,30.0,10.0,55.0,30.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,60.0,120.0,20.0,20.0,10.0,202.0,200.0,100.0,800.0,200.0,300.0,40.0,51.0,80.0,100.0,200.0,100.0,100.0,130.0,170.0,200.0,150.0,150.0,100.0,48.0,80.0,100.0,50.0,61.0,53.0,81.0,18.0,25.0,25.0,52.0,99.75,95.0,100.0,56.0,94.5,102.75,102.75,101.0,25.0,103.0,122.0,50.0,100.0,29.0,26.0,58.0,83.0,100.0,50.0,81.0,28.0,100.0,200.0,81.0,50.0,50.0,80.0,20.0,24.0,10.0,1350.0,155.0,50.0,24.0,24.0,40.0,99.0,15.0,103.5,36.0,87.0,42.0,51.0,51.0,51.0,51.0,100.0,100.0,97.0,125.0,23.0,75.0,123.0,52.0,20.0,50.0,50.0,50.0,57.0,54.0,100.0,50.0,72.0,100.0,53.0,53.0,81.0,95.0,81.0,101.0,12.0,71.0,151.0,52.0,31.0,25.0,17.0,103.0,101.0,76.5,36.0,60.0,50.0,150.0,50.0,100.0,100.0,53.0,38.0,300.0,50.0,101.0,100.0,60.0,52.0,31.0,10.0,24.0,30.0,30.0,60.0,54.0,24.0,24.0,40.0,14.0,21.0,11.0,20.0,28.0,24.0,25.0,21.0,17.0,46.0,29.0,29.0,29.0,17.0,25.0,29.0,36.0,23.0,22.0,30.0,11.0,30.0,30.0,1700.0,3000.0,51.0,101.0,1845.0,18.0,6000.0,10.0,21.0,29.0,30.0,11.0,24.0,29.0,26.0,24.0,27.0,30.0,19.0,29.0,20.0,30.0,22.0,32.0,29.0,10.0,30.0,30.0,22.0,30.0,30.0,18.0,30.0,24.0,24.0,16.0,14.0,22.0,16.0,12.0,16.0,21.0,16.0,21.0,16.0,19.0,14.0,14.0,18.0,19.0,11.0,14.0,19.0,22.0,15.0,19.0,23.0,16.0,3000.0,24.0,30.0,22.0,38.0,46.0,55.0,2330.0,2330.0,14.0,29.0,27.0,231.0,30.0,30.0,30.0,31.0,31.0,31.0,28.0,47.0,43.0,43.0,43.0,43.0,39.0,47.0,43.0,47.0,26.0,26.0,720.0,32.0,32.0,32.0,32.0,32.0,36.0,31.5,36.0,36.0,36.0,36.0,40.5,36.0,31.5,40.5,40.5,22.5,30.0,12.0,30.0,20.0,30.0,18.0,28.0,20.0,28.0,18.0,18.0,28.0,30.0,25.0,25.0,25.0,30.0,30.0,30.0,30.0,2490.0,28.0,21.0,25.0,29.0,29.0,37.8,21.0,25.2,554.0,554.0,800.0,360.0,27.0,27.0,27.0,27.0,27.0,155.0,30.0,30.0,30.0,30.0,49.0,31.0,42.0,300.0,34.0,576.0,26.0,23.0,23.0,23.0,21.0,21.0,21.0,3000.0,21.0,30.0,30.0,30.0,23.0,15.0,10.0,21.0,17.0,23.0,50.0 ...

# %% [markdown]
# ## Export to clean

# %%
df.to_parquet(OUTPUT_FILE_FULL_DATASET)
geo.to_parquet(OUTPUT_FILE_GEO)
agg.to_parquet(OUTPUT_FILE_AGG)

# %% [markdown]
# ## Conclusion
# ### Closed issues
# * Perform an initial assessment of the raw data to understand its structure, quality, and any potential issues.
# * Identify missing values, outliers, duplicates, and inconsistencies within the data.
# * Handle missing values through imputation or deletion based on the nature of the data and the analysis requirements.
# * Standardize data formats, such as converting date/time formats, ensuring consistent units, and addressing encoding issues.
# * Perform basic data transformations, such as normalization or scaling, if necessary.
# * Document all data cleaning operations performed in this stage for transparency and reproducibility.
# * Address outliers and anomalies by applying statistical methods or domain knowledge.
